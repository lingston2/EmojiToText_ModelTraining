# %%
import matplotlib.pyplot as plt
#Combine
plt.subplots(figsize=(20, 12))

#Pegasus
#Spec and title
steps = [1, 2, 3, 4]
training_loss_emojitosentence = [1.0677, 0.9666, 0.8378, 0.7592]
valdiation_loss_emojitosentence = [1.016306, 0.954075, 0.956926, 0.974730]

plt.subplot(2, 2, 1)
plt.plot(steps, training_loss_emojitosentence, label = "Training Loss", color = 'blue', marker = 'o', markerfacecolor='blue', markersize = 6)
plt.plot(steps, valdiation_loss_emojitosentence, label = "Validation Loss", color = 'green', marker = 'o', markerfacecolor='green', markersize = 6)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title("Emoji to Sentence")
plt.legend()
# plt.show()

#Review no stop
steps = [1, 2, 3, 4]
training_loss_emojitoresponse = [0, 1.4634, 0.952, 0.952]
valdiation_loss_emojitoresponse = [1.097259, 1.030365, 1.010657, 1.036266]

plt.subplot(2, 2, 2)
plt.plot(steps, training_loss_emojitoresponse, label = "Training Loss", color = 'blue', marker = 'o', markerfacecolor='blue', markersize = 6)
plt.plot(steps, valdiation_loss_emojitoresponse, label = "Validation Loss", color = 'green', marker = 'o', markerfacecolor='green', markersize = 6)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title("Emoji to Response")
plt.legend()
# plt.show()


# plt.tight_layout(4)
# plt.legend()
plt.show()
# Out:
# <ipython-input-1-113864961652>:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 2, 1)
